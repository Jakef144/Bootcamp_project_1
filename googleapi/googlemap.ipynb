# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import folium
from scipy.stats import linregress
from api_key import map_api

# %%
api_key = "map_api"
url = "https://areainsights.googleapis.com/v1:computeInsights"

# %%
# Define the function to search for rehabilitation centers in the USA
def get_rehab_centers(map_api, location="34.052235,-118.243683", radius=50000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": location,  # change location to result query of country
        "radius": radius,  # Remove radius
        "type": "health",
        "keyword": "rehabilitation",
        "key": map_api
    }
   # add countif request to count the total facilities not by location  
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("results", [])
    else:
        print("Error:", response.status_code)
        return []

# Call the function
rehab_centers = get_rehab_centers(map_api)

# %%
if rehab_centers:
    rehab_df = pd.DataFrame([{
        "Name": center.get("name"),
        "Address": center.get("vicinity"),
        "Latitude": center["geometry"]["location"]["lat"],
        "Longitude": center["geometry"]["location"]["lng"]
    } for center in rehab_centers])
    # Display the DataFrame
    display(rehab_df)
else:
    print("No results found.")
# Out:
#                                                  Name  \
# 0    Panorama Gardens Nursing & Rehabilitation Center
# 1              Victoria Healthcare and Rehabilitation
# 2                 Beverly HIlls Rehabilitation Center
# 3          Alamitos Belmont Health and Rehabilitation
# 4   Encompass Health Rehabilitation Hospital of Tu...
# 5           Newport Nursing and Rehabilitation Center
# 6                          Studio City Rehabilitation
# 7                        Covina Rehabilitation Center
# 8            Tarzana Health and Rehabilitation Center
# 9            The Rehabilitation Center of North Hills
# 10  St. Elizabeth Healthcare and Rehabilitation Ce...
# 11  California Rehabilitation and Sports Therapy -...
# 12      Laguna Hills Health and Rehabilitation Center
# 13               Rehabilitation Center of Los Angeles
# 14   Rancho Los Amigos National Rehabilitation Center
# 15                Orangegrove Rehabilitation Hospital
# 16                  The Rehabilitation Center on Pico
# 17                   Guardian Rehabilitation Hospital
# 18  Providence Little Company of Mary Medical Cent...
# 19                           Precision Rehabilitation
#
#                                          Address   Latitude   Longitude
# 0              9541 Van Nuys Blvd, Panorama City  34.243821 -118.450440
# 1                    340 Victoria St, Costa Mesa  33.652757 -117.913863
# 2            580 S San Vicente Blvd, Los Angeles  34.066139 -118.372939
# 3                      3901 E 4th St, Long Beach  33.772030 -118.147251
# 4               15120 Kensington Park Dr, Tustin  33.712670 -117.815491
# 5               1555 Superior Ave, Newport Beach  33.630928 -117.929130
# 6                11429 Ventura Blvd, Studio City  34.139838 -118.379876
# 7                         261 Badillo St, Covina  34.086657 -117.893860
# 8                      5650 Reseda Blvd, Tarzana  34.173954 -118.535801
# 9               9655 Sepulveda Blvd, North Hills  34.246093 -118.467834
# 10                 2800 N Harbor Blvd, Fullerton  33.902785 -117.928919
# 11  18682 Beach Blvd Suite 160, Huntington Beach  33.691506 -117.988177
# 12          24452 Health Center Dr, Laguna Hills  33.607420 -117.707665
# 13                340 S Alvarado St, Los Angeles  34.061569 -118.273295
# 14                    7601 Imperial Hwy., Downey  33.929375 -118.158561
# 15         12332 Garden Grove Blvd, Garden Grove  33.773869 -117.917376
# 16                 3233 W Pico Blvd, Los Angeles  34.047379 -118.313456
# 17                533 S Fairfax Ave, Los Angeles  34.066458 -118.361830
# 18        4101 Torrance Blvd 1st Floor, Torrance  33.838468 -118.357244
# 19                  3294 E Spring St, Long Beach  33.810065 -118.154380

# %% [markdown]
# Complete a population density check in each area attached to the query involved in relative location
# Commpare and combine results to the amount of deaths in the specifed country
# change query into countries not cities

# %%
# Create a map centered around the example location (Los Angeles)
m = folium.Map(location=[34.052235, -118.243683], zoom_start=10)

# Add markers for each rehabilitation center
for _, center in rehab_df.iterrows():
    folium.Marker(
        location=[center["Latitude"], center["Longitude"]],
        popup=center["Name"],
        tooltip=center["Address"]
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dba8900bd3524bddd99eb8921246626 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dba8900bd3524bddd99eb8921246626&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dba8900bd3524bddd99eb8921246626 = L.map(
#                 &quot;map_5dba8900bd3524bddd99eb8921246626&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_249bcfe99f1bf892d61b5a7bb2127ed9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_249bcfe99f1bf892d61b5a7bb2127ed9.addTo(map_5dba8900bd3524bddd99eb8921246626);
#
#
#             var marker_9ace940d07ece73ca145c70400f4504d = L.marker(
#                 [34.2438209, -118.4504403],
#                 {}
#             ).addTo(map_5dba8900bd3524bddd99eb8921246626);
#
#
#         var popup_485392194c7f49e59f3f14339a064415 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b00bcc1a4801f7c7312ad1065cb181d = $(`&lt;div id=&quot;html_2b00bcc1a4801f7c7312ad1065cb181d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Panorama Gardens Nursing &amp; Rehabilitation Center&lt;/div&gt;`)[0];
#                 popup_485392194c7f49e59f3f14339a064415.setContent(html_2b00bcc1a4801f7c7312ad1065cb181d);
#
#
#
#         marker_9ace940d07ece73ca145c70400f4504d.bindPopup(popup_485392194c7f49e59f3f14339a064415)
#         ;
#
#
#
#
#             marker_9ace940d07ece73ca145c70400f4504d.bindTooltip(
#                 `&lt;div&gt;
#                      9541 Van Nuys Blvd, Panorama City
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dc1b3e1151d75d254e8c4b81b55f00ea = L.marker(
#                 [33.6527572, -117.9138628],
#                 {}
#             ).addTo(map_5dba8900bd3524bddd99eb8921246626);
#
#
#         var popup_3b4c1f876d03b61dffc624ea18b14c23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_381370e83136aea35b136f927e8a29b8 = $(`&lt;div id=&quot;html_381370e83136aea35b136f927e8a29b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Victoria Healthcare and Rehabilitation&lt;/div&gt;`)[0];
#                 popup_3b4c1f876d03b61dffc624ea18b14c23.setContent(html_381370e83136aea35b136f927e8a29b8);
#
#
#
#         marker_dc1b3e1151d75d254e8c4b81b55f00ea.bindPopup(popup_3b4c1f876d03b61dffc624ea18b14c23)
#         ;
#
#
#
#
#             marker_dc1b3e1151d75d254e8c4b81b55f00ea.bindTooltip(
#                 `&lt;div&gt;
#                      340 Victoria St, Costa Mesa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9e31c150d1ed92e5575e0a4752769ce2 = L.marker(
#                 [34.0661394, -118.3729394],
#                 {}
#             ).addTo(map_5dba8900bd3524bddd99eb8921246626);
#
#
#         var popup_53c8e7850b12cb956d81ba0267519a43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c564d7ad801125bd4b9eb2e999abf7a = $(`&lt;div id=&quot;html_0c564d7ad801125bd4b9eb2e999abf7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beverly HIlls Rehabilitation Center&lt;/div&gt;`)[0];
#                 popup_53c8e7850b12cb956d81ba0267519a43.setContent(html_0c564d7ad801125bd4b9eb2e999abf7a);
#
#
#
#         marker_9e31c150d1ed92e5575e0a4752769ce2.bindPopup(popup_53c8e7850b12cb956d81ba0267519a43)
#         ;
#
#
#
#
#             marker_9e31c150d1ed92e5575e0a4752769ce2.bindTooltip(
#                 `&lt;div&gt;
#                      580 S San Vicente Blvd, Los Angeles
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c03322a0a48cb14b1571f2f3ac4333a5 = L.marker(
#                 [33.7720305, -118.1472514],
#                 {}
#             ).addTo(map_5dba8900bd3524bddd99eb8921246626);
#
#
#         var popup_02ac295d364b6d990d0160465d183a7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5676db1c2eb6e87ed6e841e638890c81 = $(`&lt;div id=&quot;html_5676db1c2eb6e87ed6e841e638890c81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alamitos Belmont Health and Rehabilitation&lt;/div&gt;`)[0];
#                 popup_02ac295d364b6d990d0160465d183a7e.setContent(html_5676db1c2eb6e87ed6e841e638890c81);
#
#
#
#         marker_c03322a0a48cb14b1571f2f3ac4333a5.bindPopup(popup_02ac295d364b6d990d0160465d183a7e)
#         ;
#
#
#
#
#             marker_c03322a0a48cb14b1571f2f3ac4333a5.bindTooltip(
#                 `&lt;div

# %%
# Creating the DataFrame based on provided data for demonstration
import pandas as pd
import folium

# Constructing the DataFrame with provided data
data = {
    "Name": [
        "Panorama Gardens Nursing & Rehabilitation Center", "Victoria Healthcare and Rehabilitation",
        "Beverly HIlls Rehabilitation Center", "Alamitos Belmont Health and Rehabilitation",
        "Encompass Health Rehabilitation Hospital of Tustin", "Studio City Rehabilitation",
        "Covina Rehabilitation Center", "The Rehabilitation Center of North Hills",
        "Tarzana Health and Rehabilitation Center", "St. Elizabeth Healthcare and Rehabilitation Center",
        "California Rehabilitation and Sports Therapy - Huntington Beach",
        "Laguna Hills Health and Rehabilitation Center", "Rehabilitation Center of Los Angeles",
        "Rancho Los Amigos National Rehabilitation Center", "Orangegrove Rehabilitation Hospital",
        "The Rehabilitation Center on Pico", "Providence Little Company of Mary Medical Center",
        "Precision Rehabilitation", "Huntington Drive Health and Rehabilitation Center",
        "Burbank Healthcare & Rehabilitation Center"
    ],
    "Address": [
        "9541 Van Nuys Blvd, Panorama City", "340 Victoria St, Costa Mesa", "580 S San Vicente Blvd, Los Angeles",
        "3901 E 4th St, Long Beach", "15120 Kensington Park Dr, Tustin", "11429 Ventura Blvd, Studio City",
        "261 Badillo St, Covina", "9655 Sepulveda Blvd, North Hills", "5650 Reseda Blvd, Tarzana",
        "2800 N Harbor Blvd, Fullerton", "18682 Beach Blvd Suite 160, Huntington Beach",
        "24452 Health Center Dr, Laguna Hills", "340 S Alvarado St, Los Angeles", "7601 Imperial Hwy., Downey",
        "12332 Garden Grove Blvd, Garden Grove", "3233 W Pico Blvd, Los Angeles", 
        "4101 Torrance Blvd 1st Floor, Torrance", "3294 E Spring St, Long Beach", 
        "400 Huntington Dr, Arcadia", "1041 S Main St, Burbank"
    ],
    "Latitude": [
        34.243821, 33.652757, 34.066139, 33.772030, 33.712670, 34.139838, 
        34.086657, 34.246093, 34.173954, 33.902785, 33.691593, 33.607420, 
        34.061569, 33.929375, 33.773869, 34.047379, 33.838468, 33.810065, 
        34.131191, 34.162609
    ],
    "Longitude": [
        -118.450440, -117.913863, -118.372939, -118.147251, -117.815491, 
        -118.379876, -117.893860, -118.467834, -118.535801, -117.928919, 
        -117.988178, -117.707665, -118.273295, -118.158561, -117.917376, 
        -118.313456, -118.357244, -118.154380, -118.046652, -118.311773
    ]
}
rehab_df = pd.DataFrame(data)

# Creating a Folium map centered on the average location of all facilities
map_center = [rehab_df['Latitude'].mean(), rehab_df['Longitude'].mean()]
folium_map = folium.Map(location=map_center, zoom_start=10)

# Adding markers for each facility
for idx, row in rehab_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Name: {row['Name']}<br>Address: {row['Address']}",
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(folium_map)

# Adding a marker or popup showing the total count of facilities
total_facilities = len(rehab_df)
folium.Marker(
    location=map_center,
    popup=f"Total Facilities: {total_facilities}",
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(folium_map)

# Displaying the map
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1eb3bfde66995c9d240a94bf02d7daba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1eb3bfde66995c9d240a94bf02d7daba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1eb3bfde66995c9d240a94bf02d7daba = L.map(
#                 &quot;map_1eb3bfde66995c9d240a94bf02d7daba&quot;,
#                 {
#                     center: [33.952514099999995, -118.1567427],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82851d9d52fa7459a7f11ca3f41d5940 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82851d9d52fa7459a7f11ca3f41d5940.addTo(map_1eb3bfde66995c9d240a94bf02d7daba);
#
#
#             var marker_89fa03b1e88ede25415bf822fdc4aef1 = L.marker(
#                 [34.243821, -118.45044],
#                 {}
#             ).addTo(map_1eb3bfde66995c9d240a94bf02d7daba);
#
#
#             var icon_e7998ee4d520dcaacffb1b951bc6feef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89fa03b1e88ede25415bf822fdc4aef1.setIcon(icon_e7998ee4d520dcaacffb1b951bc6feef);
#
#
#         var popup_31347af5140c9cce21e569936ba2efb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77e425c6b73f674c36455377ad84c4f3 = $(`&lt;div id=&quot;html_77e425c6b73f674c36455377ad84c4f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Panorama Gardens Nursing &amp; Rehabilitation Center&lt;br&gt;Address: 9541 Van Nuys Blvd, Panorama City&lt;/div&gt;`)[0];
#                 popup_31347af5140c9cce21e569936ba2efb0.setContent(html_77e425c6b73f674c36455377ad84c4f3);
#
#
#
#         marker_89fa03b1e88ede25415bf822fdc4aef1.bindPopup(popup_31347af5140c9cce21e569936ba2efb0)
#         ;
#
#
#
#
#             var marker_9eb50de080219c5809f211256d4116a8 = L.marker(
#                 [33.652757, -117.913863],
#                 {}
#             ).addTo(map_1eb3bfde66995c9d240a94bf02d7daba);
#
#
#             var icon_08448f6c0eea2be7b609b90bd885596b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9eb50de080219c5809f211256d4116a8.setIcon(icon_08448f6c0eea2be7b609b90bd885596b);
#
#
#         var popup_bff4581c4f1af4c914863ebac0d6b57d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24b9c024c48d8a7f7d056a2490c78cb4 = $(`&lt;div id=&quot;html_24b9c024c48d8a7f7d056a2490c78cb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Victoria Healthcare and Rehabilitation&lt;br&gt;Address: 340 Victoria St, Costa Mesa&lt;/div&gt;`)[0];
#                 popup_bff4581c4f1af4c914863ebac0d6b57d.setContent(html_24b9c024c48d8a7f7d056a2490c78cb4);
#
#
#
#         marker_9eb50de080219c5809f211256d4116a8.bindPopup(popup_bff4581c4f1af4c914863ebac0d6b57d)
#         ;
#
#
#
#
#             var marker_6e1cd2675723c9840ca98574d7b988a4 = L.marker(
#                 [34.066139, -118.372939],
#                 {}
#             ).addTo(map_1eb3bfde66995c9d240a94bf02d7daba);
#
#
#             var icon_c263925af922e8d8c9577f7e9b4929d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6e1cd2675723c9840ca98574d7b988a4.setIcon(icon_c263925af922e8d8c9577f7e9b4929d0);
#
#
#         var popup_43c37be1b98ec7f2105e0317116042a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b42168e0ef8546869d8c639e36e4ff1b = $(`&lt;div id=&quot;html_b42168e0ef8546869d8c639e36e4ff1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Beverly HIlls Rehabilitation Center&lt;br&gt;Address: 580 S San Vicente Blvd, Los Angeles&lt;/div&gt;`)[0];
#                 popup_43c37be1b98ec7f2105e0317116042a4.setContent(html_b42168e0ef8546869d8c639e36e4ff1b);
#
#
#
#         marker_6e1cd2675723c9840ca98574d7b988a4.bindPopup(popup_43c37be1b98ec7f2105e0317116042a4)
#         ;
#
#
#
#
#             var marker_ac977f672e06905c1f3f60c8bf027ed7 = L.marker(
#                 [33.77203, -118.147251],
#                 {}
#             ).addTo(map_1eb3bfde6

# %%
# Define the function to search for rehabilitation centers in the USA
def get_rehab_centers(map_api, location="40.7128, -74.0060", radius=100000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": location,  # change location to result query of country
        "radius": radius,  # Remove radius
        "type": "health",
        "keyword": "rehabilitation",
        "key": map_api
    }
   # add countif request to count the total facilities not by location  
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("results", [])
    else:
        print("Error:", response.status_code)
        return []

# Call the function
rehab_centers = get_rehab_centers(map_api)

# %%
if rehab_centers:
    rehab_df = pd.DataFrame([{
        "Name": center.get("name"),
        "Address": center.get("vicinity"),
        "Latitude": center["geometry"]["location"]["lat"],
        "Longitude": center["geometry"]["location"]["lng"]
    } for center in rehab_centers])
    # Display the DataFrame
    display(rehab_df)
else:
    print("No results found.")
# Out:
#                                                  Name  \
# 0        Buena Vida Rehabilitation and Nursing Center
# 1     Boro Park Center for Rehabilitation and Nursing
# 2           Seagate Rehabilitation and Nursing Center
# 3                        Regal Heights Rehabilitation
# 4   Bensonhurst Center for Rehabilitation & Health...
# 5                   NewYork Center For Rehabilitation
# 6       RedBank Center for Rehabilitation and Healing
# 7        Downtown Brooklyn Nursing and Rehabilitation
# 8        Sheepshead Nursing and Rehabilitation Center
# 9      Hopkins Center for Rehabilitation & Healthcare
# 10             Nassau Rehabilitation & Nursing Center
# 11        Bronx Center for Rehabilitation and Nursing
# 12        Morris Park Rehabilitation & Nursing Center
# 13                      Burke Rehabilitation Hospital
# 14      Morningside Nursing and Rehabilitation Center
# 15        The Phoenix Rehabilitation & Nursing Center
# 16  The Riverside Premier Rehabilitation and Heali...
# 17   Clove Lakes Healthcare and Rehabilitation Center
# 18         Massapequa Center Rehabilitation & Nursing
# 19                  Atlantic Rehabilitation Institute
#
#                              Address   Latitude  Longitude
# 0              48 Cedar St, Brooklyn  40.696876 -73.927667
# 1            4915 10th Ave, Brooklyn  40.638490 -73.998625
# 2           3015 W 29th St, Brooklyn  40.572405 -73.994228
# 3    70-05 35th Ave, Jackson Heights  40.750856 -73.895285
# 4             1740 84th St, Brooklyn  40.609149 -74.002534
# 5             26-13 21st St, Astoria  40.772846 -73.925153
# 6           100 Chapin Ave, Red Bank  40.338161 -74.087347
# 7          727 Classon Ave, Brooklyn  40.675149 -73.959751
# 8            2840 Knapp St, Brooklyn  40.585303 -73.931556
# 9              155 Dean St, Brooklyn  40.686656 -73.987522
# 10         1 Greenwich St, Hempstead  40.704348 -73.621588
# 11         1010 Underhill Ave, Bronx  40.826735 -73.860866
# 12         1235 Pelham Pkwy N, Bronx  40.858739 -73.851500
# 13  785 Mamaroneck Ave, White Plains  41.017425 -73.752314
# 14         1000 Pelham Pkwy S, Bronx  40.856622 -73.859492
# 15       140 St Edwards St, Brooklyn  40.692653 -73.977863
# 16        150 Riverside Dr, New York  40.790651 -73.979371
# 17      25 Fanning St, Staten Island  40.608718 -74.122576
# 18        101 Louden Ave, Amityville  40.684836 -73.423532
# 19          4 Giralda Farms, Madison  40.767190 -74.435684

# %%
# Create a map centered around the example location New york
m = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Add markers for each rehabilitation center
for _, center in rehab_df.iterrows():
    folium.Marker(
        location=[center["Latitude"], center["Longitude"]],
        popup=center["Name"],
        tooltip=center["Address"]
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7a396a24d52259385ba483de4291d7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7a396a24d52259385ba483de4291d7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7a396a24d52259385ba483de4291d7f = L.map(
#                 &quot;map_c7a396a24d52259385ba483de4291d7f&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_973d0161d2d5b9e2d72950d28b7fc8f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_973d0161d2d5b9e2d72950d28b7fc8f7.addTo(map_c7a396a24d52259385ba483de4291d7f);
#
#
#             var marker_eb13eaf0d9d6b3ecdbc081c9d8b55818 = L.marker(
#                 [34.243821, -118.45044],
#                 {}
#             ).addTo(map_c7a396a24d52259385ba483de4291d7f);
#
#
#         var popup_1774fb51c87a03307fc8fc3c133cdc26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b88603d27f17efb94b3c1bb0278c5662 = $(`&lt;div id=&quot;html_b88603d27f17efb94b3c1bb0278c5662&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Panorama Gardens Nursing &amp; Rehabilitation Center&lt;/div&gt;`)[0];
#                 popup_1774fb51c87a03307fc8fc3c133cdc26.setContent(html_b88603d27f17efb94b3c1bb0278c5662);
#
#
#
#         marker_eb13eaf0d9d6b3ecdbc081c9d8b55818.bindPopup(popup_1774fb51c87a03307fc8fc3c133cdc26)
#         ;
#
#
#
#
#             marker_eb13eaf0d9d6b3ecdbc081c9d8b55818.bindTooltip(
#                 `&lt;div&gt;
#                      9541 Van Nuys Blvd, Panorama City
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4606ab65729fcce355c8a7398f5ff4ff = L.marker(
#                 [33.652757, -117.913863],
#                 {}
#             ).addTo(map_c7a396a24d52259385ba483de4291d7f);
#
#
#         var popup_6b465f53c076eb4959f0a7c74f88ad5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4591b0d62ffdd224cbf6db67207e2c51 = $(`&lt;div id=&quot;html_4591b0d62ffdd224cbf6db67207e2c51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Victoria Healthcare and Rehabilitation&lt;/div&gt;`)[0];
#                 popup_6b465f53c076eb4959f0a7c74f88ad5d.setContent(html_4591b0d62ffdd224cbf6db67207e2c51);
#
#
#
#         marker_4606ab65729fcce355c8a7398f5ff4ff.bindPopup(popup_6b465f53c076eb4959f0a7c74f88ad5d)
#         ;
#
#
#
#
#             marker_4606ab65729fcce355c8a7398f5ff4ff.bindTooltip(
#                 `&lt;div&gt;
#                      340 Victoria St, Costa Mesa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79b792f4c48357c267912320607b13e4 = L.marker(
#                 [34.066139, -118.372939],
#                 {}
#             ).addTo(map_c7a396a24d52259385ba483de4291d7f);
#
#
#         var popup_67ae519b2bb97a9f878e73ed32694bad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25b5cd01a7ce0c0349506dda9a4808ca = $(`&lt;div id=&quot;html_25b5cd01a7ce0c0349506dda9a4808ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beverly HIlls Rehabilitation Center&lt;/div&gt;`)[0];
#                 popup_67ae519b2bb97a9f878e73ed32694bad.setContent(html_25b5cd01a7ce0c0349506dda9a4808ca);
#
#
#
#         marker_79b792f4c48357c267912320607b13e4.bindPopup(popup_67ae519b2bb97a9f878e73ed32694bad)
#         ;
#
#
#
#
#             marker_79b792f4c48357c267912320607b13e4.bindTooltip(
#                 `&lt;div&gt;
#                      580 S San Vicente Blvd, Los Angeles
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_11b0c04c33fbd77fd151359581703497 = L.marker(
#                 [33.77203, -118.147251],
#                 {}
#             ).addTo(map_c7a396a24d52259385ba483de4291d7f);
#
#
#         var popup_d72b968b919b2bad5aed513441052367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ac490b8ab90f0b76f4ba626d8bf60ff = $(`&lt;div id=&quot;html_2ac490b8ab90f0b76f4ba626d8bf60ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alamitos Belmont Health and Rehabilitation&lt;/div&gt;`)[0];
#                 popup_d72b968b919b2bad5aed513441052367.setContent(html_2ac490b8ab90f0b76f4ba626d8bf60ff);
#
#
#
#         marker_11b0c04c33fbd77fd151359581703497.bindPopup(popup_d72b968b919b2bad5aed513441052367)
#         ;
#
#
#
#
#             marker_11b0c04c33fbd77fd151359581703497.bindTooltip(
#                 `&lt;div&gt;
